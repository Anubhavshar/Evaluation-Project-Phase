# %% [markdown]
# # Project2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing CSV file

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\avocado.csv (2).zip')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
# Out:
# No of Rows: 18249
# No of Columns: 14

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.drop(['Unnamed: 0'],inplace=True,axis=1)
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# Observation

# %% [markdown]
# The dataset doesnot contain any null values

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking duplicate values

# %%
print('The total number of dupicate rows are:',df.duplicated().sum())
# Out:
# The total number of dupicate rows are: 0

# %% [markdown]
# Observation

# %% [markdown]
# The dataset doesnot contain any duplicate values

# %% [markdown]
# # Statistical Analysis

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
#
#                     50%        75%          max
# AveragePrice       1.37       1.66         3.25
# Total Volume  107376.76  432962.29  62505646.52
# 4046            8645.30  111020.20  22743616.17
# ...

# %% [markdown]
# Observation

# %% [markdown]
# All columns value of mean is greater than median. Data is right skewed.
# The value of std. deviation is greater than mean i.e. data is spread.

# %%
sns.heatmap(df.describe())
# Out:
# <AxesSubplot:>

# %%
#divide the date and month into two columns.
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %%
df.drop(columns=['Date'], inplace = True) #drop Date column

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12   27
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12   20
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12   13
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12    6
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11   29

# %%
plt.figure(figsize=(15,20), facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize=15)
    plotnumber+=1
plt.show()

# %% [markdown]
# Obsevation

# %% [markdown]
# 1.We can see skewed data with presence of outliers with sharp peak.

# %% [markdown]
# Most of the plots are right skewed, having value of mean very small compare to std. deviation & median.
# This is resulting in sharp high peak.
# Very few data points are present as we move away from zero to other end of x-axis.

# %%
plt.figure(figsize=(12,7))
plt.title('Price')
sns.distplot(df["AveragePrice"], color='b')
# Out:
# <AxesSubplot:title={'center':'Price'}, xlabel='AveragePrice', ylabel='Density'>

# %%
df.hist(bins=30,figsize=(30,15))
plt.show()

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# Observation

# %% [markdown]
# The avacado id divided into two types namely conventional and organic

# %%
plt.figure(figsize=(8,6))
sns.barplot(y="type", x="AveragePrice", data=df, palette = 'hsv')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='type'>

# %% [markdown]
# Observation

# %% [markdown]
# 1.The Oraganic Avocado is almost much costlier than conventional Avacado.

# %% [markdown]
# 2.Average Price of Organic Avocado is higher than Conventional Avocado.

# %%
plt.pie(df['type'].value_counts(),labels=['organic','conventional'],autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='year', y='Total Volume', hue='type',data=df, palette='coolwarm',ci=68)
plt.show()

# %% [markdown]
# Observation

# %% [markdown]
# 1.The sell of organic avacodo is less.
#
# 2.Conventional Avacado are in more demand.

# %%
df.groupby(['year','type'])['AveragePrice'].agg([min,max])
# Out:
#                     min   max
# year type
# 2015 conventional  0.49  1.59
#      organic       0.81  2.79
# 2016 conventional  0.51  2.20
#      organic       0.58  3.25
# 2017 conventional  0.46  2.22
#      organic       0.44  3.17
# 2018 conventional  0.56  1.74
#      organic       1.01  2.30

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='year', y='AveragePrice', hue='type',data=df, palette='coolwarm',ci=68)
plt.show()

# %% [markdown]
# Observation

# %% [markdown]
# 1. It is clearly visible that from year 2015 to year 2018 the sell of organic is higher than the conventional

# %%
df.groupby(['region'])['type','AveragePrice'].agg([sum])
# Out:
#                                                                   type  \
#                                                                    sum
# region
# Albany               conventionalconventionalconventionalconvention...
# Atlanta              conventionalconventionalconventionalconvention...
# BaltimoreWashington  conventionalconventionalconventionalconvention...
# Boise                conventionalconventionalconventionalconvention...
# Boston               conventionalconventionalconventionalconvention...
# BuffaloRochester     conventionalconventionalconventionalconvention...
# California           conventionalconventionalconventionalconvention...
# Charlotte            conventionalconventionalconventionalconvention...
# Chicago              conventionalconventionalconventionalconvention...
# CincinnatiDayton     conventionalconventionalconventionalconvention...
# Columbus             conventionalconventionalconventionalconvention...
# ...

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12   27
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12   20
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12   13
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12    6
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11   29

# %%
sns.countplot('year',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x="Month", y="AveragePrice", hue='type', data=df)
plt.show()

# %% [markdown]
# Observation

# %% [markdown]
# 1.In month of September and October Price of Conventional type of Avacado is comparatively lower than other months.
# 2.There is not much upheaval in Organic type Avacoda over year peroid.
# 3.We can see that variation in mean price values in above groupby table, which confirm what we got from barplot.

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['region'],y=df['AveragePrice'], data=df)
plt.title('Bar Plot')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
p=1
        
x=df['year']
y=df[['4046','4225','4770']]
for i in y:
    if p<=9:
        plt.subplot(3,3,p)
        sns.barplot(x,y[i])
        plt.xlabel('year')
        plt.ylabel(i)
    p+=1

plt.show()

# %% [markdown]
# observation

# %% [markdown]
# Production of PLU 4046 has grown over the 4 years and is greater than the production of PLU 4225 and PLU 4770, which is least produced.

# %%
plt.figure(figsize=(10,10))
p=1
        
x=df['year']
y=df[['Small Bags','Large Bags','XLarge Bags']]
for i in y:
    if p<=9:
        plt.subplot(3,3,p)
        sns.barplot(x,y[i])
        plt.xlabel('year')
        plt.ylabel(i)
    p+=1

plt.show()

# %% [markdown]
# Observation

# %% [markdown]
# 1.Sale of all 3 types of bags has grown over the years.
# 2.Most of customers prefer buying Small Bags over Large and Xlarge bags.
# 3.There is very narrow Customer segment willing to buy XLarge type bags possiblily more quantity need to consume and price associated with it.

# %% [markdown]
# # Encoding of data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['region']=le.fit_transform(df['region'])
df['type']=le.fit_transform(df['type'])
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Month  Day
# 0     8603.62       93.25          0.0     0  2015       0     12   27
# 1     9408.07       97.49          0.0     0  2015       0     12   20
# 2     8042.21      103.14          0.0     0  2015       0     12   13
# 3     5677.40      133.76          0.0     0  2015       0     12    6
# 4     5986.26      197.69          0.0     0  2015       0     11   29

# %% [markdown]
# # Checking outliers

# %%
plt.figure(figsize=(18,15), facecolor='white')
plotnumber =1
for column in df:
    if plotnumber <=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.boxplot(df[column], palette='hsv')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation

# %% [markdown]
# We can see that most of the features contain outliers so we have remove them

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

# %%
df1.shape
# Out:
# (17651, 14)

# %% [markdown]
# Observation

# %% [markdown]
#  The shape of the dataset after removing outliers

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# # Correlation

# %%
df1.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.332056 -0.333577 -0.243988 -0.243465
# Total Volume     -0.332056      1.000000  0.876307  0.871592  0.647518
# 4046             -0.333577      0.876307  1.000000  0.565118  0.492127
# 4225             -0.243988      0.871592  0.565118  1.000000  0.620221
# 4770             -0.243465      0.647518  0.492127  0.620221  1.000000
# Total Bags       -0.297323      0.912184  0.727981  0.757786  0.557980
# Small Bags       -0.275771      0.905648  0.706800  0.778761  0.571512
# Large Bags       -0.270915      0.640642  0.561060  0.451711  0.323747
# XLarge Bags      -0.152669      0.513741  0.415432  0.392030  0.495976
# type              0.613150     -0.415476 -0.341376 -0.383138 -0.321809
# year              0.091704     -0.004866 -0.034636 -0.040234 -0.082054
# region           -0.003242      0.076676  0.119067  0.011002 -0.095972
# ...

# %%
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (18,6))
df1.corr()['AveragePrice'].drop(['AveragePrice']).plot(kind='bar',color = 'c')
plt.xlabel('Variables',fontsize=15)
plt.ylabel('AveragePrice',fontsize=15)
plt.title('Correlation of other variables with Target Variable Average Price',fontsize = 18)
plt.show()

# %% [markdown]
# Observation

# %% [markdown]
# 1.4046,4225,4770 are shows multicollinearity with Total Volume. These feature are nothing but Total avacado sold under particular grade, which are already counted in Total Volume. As we do not have any price data according each grade of avacado. These feature doesnot have any meaning in ML model.So gone drop them.

# %% [markdown]
# 2.Same goes with Total bags. Total bags is sum of all other type of bags. We gone keep drop Total bags and going to keep other differnt size bags counts features.
# Next is region feature, we also going drop this as it very poorly correlated with other features.

# %%
df1.drop(columns=['4046','4225','4770','region'],axis=1, inplace=True)

# %%
df1.head()
# Out:
#    AveragePrice  Total Volume  Total Bags  Small Bags  Large Bags  \
# 0          1.33      64236.62     8696.87     8603.62       93.25
# 1          1.35      54876.98     9505.56     9408.07       97.49
# 2          0.93     118220.22     8145.35     8042.21      103.14
# 3          1.08      78992.15     5811.16     5677.40      133.76
# 4          1.28      51039.60     6183.95     5986.26      197.69
#
#    XLarge Bags  type  year  Month  Day
# 0          0.0     0  2015     12   27
# 1          0.0     0  2015     12   20
# 2          0.0     0  2015     12   13
# 3          0.0     0  2015     12    6
# 4          0.0     0  2015     11   29

# %%
df1.drop(columns=['Total Bags'],inplace=True,axis=1)

# %% [markdown]
# # Skewness

# %%
df1.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# Month           0.107408
# Day             0.011778
# dtype: float64

# %% [markdown]
# # Removing skewness

# %%
df1['Total Volume']=np.cbrt(df1['Total Volume'])
df1['Small Bags']=np.cbrt(df1['Small Bags'])
df1['Large Bags']=np.cbrt(df1['Large Bags'])
df1['XLarge Bags']=np.cbrt(df1['XLarge Bags'])

# %%
df1.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    1.240435
# Small Bags      1.246033
# Large Bags      1.276213
# XLarge Bags     2.277028
# type           -0.037741
# year            0.229976
# Month           0.107408
# Day             0.011778
# dtype: float64

# %%
df1['Large Bags']=np.sqrt(df1['Large Bags'])
df1['XLarge Bags']=np.sqrt(df1['XLarge Bags'])

# %%
df1.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    1.240435
# Small Bags      1.246033
# Large Bags      0.018991
# XLarge Bags     1.308244
# type           -0.037741
# year            0.229976
# Month           0.107408
# Day             0.011778
# dtype: float64

# %%
df1['XLarge Bags']=np.sqrt(df1['XLarge Bags'])
df1.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    1.240435
# Small Bags      1.246033
# Large Bags      0.018991
# XLarge Bags     0.923450
# type           -0.037741
# year            0.229976
# Month           0.107408
# Day             0.011778
# dtype: float64

# %% [markdown]
# # Scaling Of Data

# %%
x=df1.drop(['AveragePrice'],axis=1)
y=df1['AveragePrice']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[-0.36001678, -0.51777267, -0.69824393, ..., -1.21001338,
#          1.64461178,  1.28930873],
#        [-0.41358063, -0.49083398, -0.69097385, ..., -1.21001338,
#          1.64461178,  0.49165249],
#        [-0.12385558, -0.53758434, -0.68168504, ..., -1.21001338,
#          1.64461178, -0.30600376],
#        ...,
#        [-0.78062205, -0.49266718, -0.81885499, ...,  1.98075592,
#         -1.46287832,  0.60560338],
#        [-0.74560645, -0.4441099 , -0.79467391, ...,  1.98075592,
#         -1.46287832, -0.19205286],
#        [-0.72856457, -0.41362468, -0.8855869 , ...,  1.98075592,
#         -1.46287832, -0.98970911]])

# %% [markdown]
# # VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif =pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
vif['Features'] = x.columns
vif
# Out:
#          vif      Features
# 0  35.440365  Total Volume
# 1  27.260234    Small Bags
# 2   7.167471    Large Bags
# 3   2.985331   XLarge Bags
# 4   4.935159          type
# 5  19.797448          year
# 6   4.063956         Month
# 7   4.200685           Day

# %% [markdown]
# Observation

# %% [markdown]
# Removing Some of highly correlated features. But this will not work here as most of input features are correlated with each other either moderated or poorly.
# Another way to address Multicollinerity is to Scaled Data and then apply PCA.

# %%
from sklearn.decomposition import PCA
pca = PCA()

# %%
x_pca = pca.fit_transform(x_scaled)
plt.figure(figsize=(6,6))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=7)
x_new = pca_new.fit_transform(x_scaled)

# %%
p_x=pd.DataFrame(x_new,columns=np.arange(7))
p_x
# Out:
#               0         1         2         3         4         5         6
# 0     -0.666728 -2.183615  1.248390 -0.069060 -0.324390 -0.192031 -1.135506
# 1     -0.678629 -2.159244  0.455389 -0.144161 -0.343927 -0.205895 -1.130120
# 2     -0.555842 -2.158581 -0.345652 -0.180849 -0.308465 -0.137729 -1.118374
# 3     -0.665071 -2.122136 -1.135304 -0.275773 -0.334722 -0.285057 -1.117199
# 4     -0.698950 -1.979362  1.465677  0.126986 -0.255500 -0.368341 -1.112676
# ...         ...       ...       ...       ...       ...       ...       ...
# 17646 -1.227833  2.409349 -1.220796 -0.646546 -0.049354  0.355216 -0.110040
# 17647 -1.324475  2.530558  1.491043 -0.205258 -0.050213  0.304382 -0.123889
# 17648 -1.457358  2.518017  0.695210 -0.223513 -0.303889  0.501712 -0.157932
# 17649 -1.408526  2.537505 -0.099972 -0.290407 -0.293838  0.523922 -0.147235
# 17650 -1.422794  2.547571 -0.895164 -0.343079 -0.367566  0.593774 -0.150928
#
# [17651 rows x 7 columns]

# %%
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(p_x.values,i) for i in range(p_x.shape[1])]
vif['Features']= p_x.columns
vif
# Out:
#    VIF  Features
# 0  1.0         0
# 1  1.0         1
# 2  1.0         2
# 3  1.0         3
# 4  1.0         4
# 5  1.0         5
# 6  1.0         6

# %% [markdown]
# # Modelling of data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from sklearn.model_selection import cross_val_score

# %%
x_train,x_test,y_train,y_test = train_test_split(p_x,y,test_size = 0.33, random_state=43)
print('Training feature matrix size:',x_train.shape)
print('Training target vector size:',y_train.shape)
print('Test feature matrix size:',x_test.shape)
print('Test target vector size:',y_test.shape)
# Out:
# Training feature matrix size: (11826, 7)
# Training target vector size: (11826,)
# Test feature matrix size: (5825, 7)
# Test target vector size: (5825,)

# %%
maxR2_score=0
maxRS=0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(p_x, y, random_state=i, test_size=.30)
    lin_reg=LinearRegression()
    lin_reg.fit(x_train,y_train)
    y_pred=lin_reg.predict(x_test)
    R2=r2_score(y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.48907915535275803 on Random_state 108

# %% [markdown]
# # Linear Regression

# %%
x_train,x_test,y_train,y_test = train_test_split(p_x,y,test_size = 0.30, random_state=42)
lin_reg=LinearRegression()
lin_reg.fit(x_train,y_train)
lin_reg.score(x_train,y_train)
y_pred=lin_reg.predict(x_test)
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('The r2 score is:',r2_score(y_test,y_pred))
print('\n')
score = cross_val_score(lin_reg, p_x,y, cv = 5)

print("Score :" ,score)
print("Mean Score :",score.mean())
# Out:
# Mean absolute error : 0.22305995984178362
# Mean squared error : 0.07946095702346338
# Root Mean Squared Error: 0.28188819951084043
# The r2 score is: 0.46673107473728936
#
#
# Score : [-0.27315079  0.12899301  0.42759801  0.10104183  0.11285195]
# Mean Score : 0.09946680101676794

# %% [markdown]
# # Random Forest Regressor

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
rfr.score(x_train,y_train)
y_pred=rfr.predict(x_test)
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('The r2 score is:',r2_score(y_test,y_pred))
print('\n')
score = cross_val_score(rfr, p_x,y, cv = 5)

print("Score :" ,score)
print("Mean Score :",score.mean())
# Out:
# Mean absolute error : 0.16324684667673717
# Mean squared error : 0.047221833517749244
# Root Mean Squared Error: 0.21730585247008247
# The r2 score is: 0.6830904465257194
#
#
# Score : [-0.15027385  0.47384701  0.49525223  0.06759236 -0.53836089]
# Mean Score : 0.06961137256818162

# %% [markdown]
# # AdaBoost Regressor

# %%
abr = AdaBoostRegressor()
abr.fit(x_train,y_train)
abr.score(x_train,y_train)
y_pred=abr.predict(x_test)
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('The r2 score is:',r2_score(y_test,y_pred))
print('\n')
score = cross_val_score(abr, p_x,y, cv = 5)

print("Score :" ,score)
print("Mean Score :",score.mean())
# Out:
# Mean absolute error : 0.21984504892243134
# Mean squared error : 0.07503519727174589
# Root Mean Squared Error: 0.2739255323472894
# The r2 score is: 0.4964327072707668
#
#
# Score : [-0.90061817  0.25140581  0.47944047 -0.00635233  0.08031877]
# Mean Score : -0.019161090205287046

# %% [markdown]
# # SVR

# %%
svr = SVR()
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
y_pred=svr.predict(x_test)
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('The r2 score is:',r2_score(y_test,y_pred))
print('\n')
score = cross_val_score(svr, p_x,y, cv = 5)

print("Score :" ,score)
print("Mean Score :",score.mean())
# Out:
# Mean absolute error : 0.18434023300221292
# Mean squared error : 0.05723841311972161
# Root Mean Squared Error: 0.23924550804502392
# The r2 score is: 0.6158683686746442
#
#
# Score : [-0.33513635  0.41473371  0.36661955 -0.06216505 -1.69209953]
# Mean Score : -0.26160953315744917

# %% [markdown]
# # KNeighbors Regressor

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
y_pred=knn.predict(x_test)
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('The r2 score is:',r2_score(y_test,y_pred))
print('\n')
score = cross_val_score(knn, p_x,y, cv = 5)

print("Score :" ,score)
print("Mean Score :",score.mean())
# Out:
# Mean absolute error : 0.18896978851963747
# Mean squared error : 0.061875350453172204
# Root Mean Squared Error: 0.2487475637130386
# The r2 score is: 0.5847495062679207
#
#
# Score : [-0.44320059  0.34450673  0.47946365 -0.05164183 -0.23118786]
# Mean Score : 0.019588020351150905

# %% [markdown]
# # Gradient Boosting Regressor

# %%
gbr= GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbr.score(x_train,y_train)
y_pred=gbr.predict(x_test)
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('The r2 score is:',r2_score(y_test,y_pred))
print('\n')
score = cross_val_score(gbr, p_x,y, cv = 5)

print("Score :" ,score)
print("Mean Score :",score.mean())
# Out:
# Mean absolute error : 0.18907645759350256
# Mean squared error : 0.058367872091343705
# Root Mean Squared Error: 0.2415944372110908
# The r2 score is: 0.6082884779397846
#
#
# Score : [-0.3109959   0.40734277  0.52239753  0.12550208  0.0369632 ]
# Mean Score : 0.1562419350195332

# %% [markdown]
# # Lasso

# %%
la=Lasso()
la.fit(x_train,y_train)
la.score(x_train,y_train)
y_pred=la.predict(x_test)
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('The r2 score is:',r2_score(y_test,y_pred))
print('\n')
score = cross_val_score(la, p_x,y, cv = 5)

print("Score :" ,score)
print("Mean Score :",score.mean())
# Out:
# Mean absolute error : 0.3145348841118913
# Mean squared error : 0.14904440759072823
# Root Mean Squared Error: 0.3860626990408789
# The r2 score is: -0.0002491038316565497
#
#
# Score : [-3.85189856 -0.63909317 -0.04763459 -0.44449249 -0.80022956]
# Mean Score : -1.156669674837169

# %% [markdown]
# # Ridge

# %%
rdg=Ridge()
rdg.fit(x_train,y_train)
rdg.score(x_train,y_train)
y_pred=rdg.predict(x_test)
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('The r2 score is:',r2_score(y_test,y_pred))
print('\n')
score = cross_val_score(rdg, p_x,y, cv = 5)

print("Score :" ,score)
print("Mean Score :",score.mean())
# Out:
# Mean absolute error : 0.22306019491074072
# Mean squared error : 0.07946091599809618
# Root Mean Squared Error: 0.28188812674196867
# The r2 score is: 0.46673135006185507
#
#
# Score : [-0.27326583  0.12902543  0.42758764  0.10105259  0.11287651]
# Mean Score : 0.09945526988438502

# %% [markdown]
# # Decision Tree Regressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
y_pred=dtr.predict(x_test)
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('The r2 score is:',r2_score(y_test,y_pred))
print('\n')
score = cross_val_score(dtr, p_x,y, cv = 5)

print("Score :" ,score)
print("Mean Score :",score.mean())
# Out:
# Mean absolute error : 0.20974320241691846
# Mean squared error : 0.0876691842900302
# Root Mean Squared Error: 0.2960898246985705
# The r2 score is: 0.41164499602996074
#
#
# Score : [-1.18696829  0.08947469 -0.02833883 -0.47611487 -2.0569333 ]
# Mean Score : -0.731776119703017

# %% [markdown]
# # We came to know that random Forest Regressor has the highest R2 score

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'n_estimators':[30,60,80],'max_depth': [10,20,40],
             'min_samples_leaf':[5,10],'criterion':['mse','mae'],
             'max_features':["auto","sqrt","log2"]}

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameter,cv=5,n_jobs = -1,verbose = 3)

# %%
from sklearn.ensemble import RandomForestRegressor
Model =  RandomForestRegressor(n_estimators=60 ,criterion = 'mse', max_depth= 20, max_features = 'auto',
             min_samples_leaf = 5, min_samples_split = 10)
Model.fit(x_train,y_train)
y_pred=Model.predict(x_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(y_test,y_pred)) 
print('\n')
# Out:
#  Error in Final Model :
# Mean absolute error : 0.1643478442232315
# Mean squared error : 0.047331097076739534
# Root Mean Squared Error: 0.21755711221823923
#
#
#  R2 Score of Final Model :
# 0.6823571699222684

# %%
import joblib
import pickle

# %%
filename="Avacado.pkl"
pickle.dump(Model,open(filename,'wb'))
